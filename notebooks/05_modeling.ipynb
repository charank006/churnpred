# %% [markdown]
# # 05. Model Training and Evaluation
#
# In this notebook, we train various classification models (e.g., Logistic Regression, Random Forest, XGBoost), tune hyper-parameters, and evaluate their performances.
